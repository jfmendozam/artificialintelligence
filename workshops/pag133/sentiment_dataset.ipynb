# %%
import pandas as pd

# %%
data = pd.read_csv("sentiment/datasets/hotel_reviews.csv")

# %%
data.head()
# Out:
#    Index             Name                  Area Review_Date  \
# 0      0  Hotel The Pearl  Paharganj, New Delhi      Jul-23
# 1      1  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 2      2  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 3      3  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 4      4  Hotel The Pearl  Paharganj, New Delhi      Aug-23
#
#                             Rating_attribute  Rating(Out of 10)  \
# 0                 Best budget friendly hotel                9.0
# 1                              Amazing place                9.0
# 2               Overall good stay. Economic.                9.0
# 3                                     Lovely                9.0
# 4  Great hotel Great staff and great staying                9.0
#
#                                          Review_Text
# 0  Hotel the pearl is perfect place to stay in De...
# 1  Location of the hotel is perfect. The hotel is...
# 2                             Location, Indian food.
# ...

# %%
data.tail()
# Out:
#       Index             Name                    Area Review_Date  \
# 6996   6996  FabHotel F9 NSP  North Delhi, New Delhi      Aug-23
# 6997   6997  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
# 6998   6998  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
# 6999   6999  FabHotel F9 NSP  North Delhi, New Delhi      Jun-23
# 7000   7000  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
#
#                 Rating_attribute  Rating(Out of 10)  \
# 6996  I'd like to thank Manager.               10.0
# 6997                      Superb                9.0
# 6998                    fabulous               10.0
# 6999                   well done               10.0
# 7000                         Bad                2.0
#
#                                             Review_Text
# 6996  The room was good, comfortable and aesthetic \...
# 6997                                         good hotel
# 6998  good experience for me about hotel \nvery good...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              7001 non-null   int64
#  1   Name               7001 non-null   object
#  2   Area               7001 non-null   object
#  3   Review_Date        7001 non-null   object
#  4   Rating_attribute   7001 non-null   object
#  5   Rating(Out of 10)  7001 non-null   float64
#  6   Review_Text        6994 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 383.0+ KB

# %%
data.shape
# Out:
# (7001, 7)

# %%
data.describe()
# Out:
#             Index  Rating(Out of 10)
# count  7001.00000        7001.000000
# mean   3500.00000           7.030981
# std    2021.15895           2.882846
# min       0.00000           1.000000
# 25%    1750.00000           6.000000
# 50%    3500.00000           8.000000
# 75%    5250.00000           9.000000
# max    7000.00000          10.000000

# %%
def describe_with_plots(df):
    import seaborn as sns
    import matplotlib.pyplot as plt

    display(df.describe())

    num_cols = df.select_dtypes(include="number")
    num_cols.hist(figsize=(12, 8), bins=20, color="lightcoral", edgecolor="black")
    plt.suptitle("Distribuciones automáticas", fontsize=14)
    plt.show()

# %%
#! pip install --upgrade numpy scipy seaborn matplotlib

describe_with_plots(data)
# Out:
#             Index  Rating(Out of 10)
# count  7001.00000        7001.000000
# mean   3500.00000           7.030981
# std    2021.15895           2.882846
# min       0.00000           1.000000
# 25%    1750.00000           6.000000
# 50%    3500.00000           8.000000
# 75%    5250.00000           9.000000
# max    7000.00000          10.000000

# %%
#! pip install ydata-profiling
#! pip install --upgrade pip
#! pip install --upgrade numpy==1.26.4 scipy==1.13.1 pandas==2.2.3 seaborn==0.13.2 matplotlib==3.8.4 ydata-profiling==4.8.3
#! pip install --upgrade ydata-profiling

#! pip install ipywidgets


from ydata_profiling import ProfileReport
from IPython.display import display  # correct import for IPython 9+

# Create the profile report
profile = ProfileReport(data, title="Análisis exploratorio", explorative=True)

# Display it in the notebook
display(profile.to_notebook_iframe())
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00, 11.85it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-11-08 16:34:33.519244&quot; name=date&gt;&lt;title&gt;Análisis exploratorio&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
#!pip install pandasgui
#!pip install qgrid
#pip install itables

import pandas as pd
import ipywidgets as widgets
from IPython.display import display

display(data)
# Out:
#       Index             Name                    Area Review_Date  \
# 0         0  Hotel The Pearl    Paharganj, New Delhi      Jul-23
# 1         1  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# 2         2  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# 3         3  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# 4         4  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# ...     ...              ...                     ...         ...
# 6996   6996  FabHotel F9 NSP  North Delhi, New Delhi      Aug-23
# 6997   6997  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
# 6998   6998  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
# 6999   6999  FabHotel F9 NSP  North Delhi, New Delhi      Jun-23
# 7000   7000  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
#
#                                Rating_attribute  Rating(Out of 10)  \
# 0                    Best budget friendly hotel                9.0
# ...

# %%
#!pip install dtale

import dtale

d = dtale.show(data)
d.open_browser()  # Esto abrirá una ventana en tu navegador con la interfaz

# %%
data.columns
# Out:
# Index(['Index', 'Name', 'Area', 'Review_Date', 'Rating_attribute',
#        'Rating(Out of 10)', 'Review_Text'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Index                  int64
# Name                  object
# Area                  object
# Review_Date           object
# Rating_attribute      object
# Rating(Out of 10)    float64
# Review_Text           object
# dtype: object

# %%
missing_values = data.isnull().any(axis=1)
print("Rows with Missing Values:")
print(missing_values)
# Out:
# Rows with Missing Values:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6996    False
# 6997    False
# 6998    False
# 6999    False
# 7000    False
# Length: 7001, dtype: bool

# %%
duplicates = data[data.duplicated()]
print("Duplicated Rows:")
print(duplicates)
# Out:
# Duplicated Rows:
# Empty DataFrame
# Columns: [Index, Name, Area, Review_Date, Rating_attribute, Rating(Out of 10), Review_Text]
# Index: []

# %%
data.dropna(axis=0, inplace=True)

# %%
data.drop_duplicates(inplace=True)

# %%
#! pip install textblob
from textblob import TextBlob
import seaborn as sns

# %%
data.head()
# Out:
#    Index             Name                  Area Review_Date  \
# 0      0  Hotel The Pearl  Paharganj, New Delhi      Jul-23
# 1      1  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 2      2  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 3      3  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 4      4  Hotel The Pearl  Paharganj, New Delhi      Aug-23
#
#                             Rating_attribute  Rating(Out of 10)  \
# 0                 Best budget friendly hotel                9.0
# 1                              Amazing place                9.0
# 2               Overall good stay. Economic.                9.0
# 3                                     Lovely                9.0
# 4  Great hotel Great staff and great staying                9.0
#
#                                          Review_Text
# 0  Hotel the pearl is perfect place to stay in De...
# 1  Location of the hotel is perfect. The hotel is...
# 2                             Location, Indian food.
# ...

# %%
def sentiment_analysis(text):
    analysis = TextBlob(str(text))
    return analysis.sentiment.polarity

# %%
data["Sentiment"] = data["Review_Text"].apply(sentiment_analysis)

# %%
print("DataFrame with Sentiment Column: ")
print(data.head())
# Out:
# DataFrame with Sentiment Column:
#    Index             Name                  Area Review_Date  \
# 0      0  Hotel The Pearl  Paharganj, New Delhi      Jul-23
# 1      1  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 2      2  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 3      3  Hotel The Pearl  Paharganj, New Delhi      Aug-23
# 4      4  Hotel The Pearl  Paharganj, New Delhi      Aug-23
#
#                             Rating_attribute  Rating(Out of 10)  \
# 0                 Best budget friendly hotel                9.0
# 1                              Amazing place                9.0
# 2               Overall good stay. Economic.                9.0
# 3                                     Lovely                9.0
# 4  Great hotel Great staff and great staying                9.0
#
#                                          Review_Text  sentiment
# 0  Hotel the pearl is perfect place to stay in De...   0.483333
# ...

# %%
correlation_coefficient = data["Rating(Out of 10)"].corr(data["sentiment"])

# %%
print(f"\nCorrelation Coefficient between Rating & Sentiment {correlation_coefficient}\n")
# Out:
# Correlation Coefficient between Rating & Sentiment 0.47056570148282684

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
colors = data["Sentiment"].apply(lambda x: 'red' if x < 0 else 'gray' if x == 0 else 'green')
plt.scatter(data["Rating(Out of 10)"], data["Sentiment"], c=colors, alpha=0.7)
plt.title("Correlation Between Ratings and Sentiment")
plt.xlabel("Rating")
plt.ylabel("Sentiment Polarity")
plt.show()

# %%
import nltk
from nltk.corpus import stopwords
from nltk import pos_tag

# %%
nltk.download("stopwords")
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package stopwords to /home/jf/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jf/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jf/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def sentiment_analysis_blob(text):
    analysis = TextBlob(str(text))
    return "Positive" if analysis.sentiment.polarity > 0 else "Negative" if analysis.sentiment.polarity < 0 else "Neutral"

# %%
data["Sentiment"] = data["Rating_attribute"].apply(sentiment_analysis_blob)

# %%
positive_reviews = "".join(data[data["Sentiment"] == "Positive"]["Rating_attribute"])
negative_reviews = "".join(data[data["Sentiment"] == "Negative"]["Rating_attribute"])

# %%
from collections import Counter
from  nltk.tokenize import word_tokenize

# %%
stopwords_set = set(stopwords.words("english"))

# %%
positive_tokens = word_tokenize(positive_reviews)
negative_tokens = word_tokenize(negative_reviews)

# %%
positive_tokens = [word.lower() for word in positive_tokens if word.isalpha() and word.lower() not in stopwords_set]
negative_tokens = [word.lower() for word in negative_tokens if word.isalpha() and word.lower() not in stopwords_set]

# %%
top_positive_keywords = Counter(positive_tokens).most_common(5)
top_negative_keywords = Counter(negative_tokens).most_common(5)

# %%
print("Top 5 Keywords that are frequently used in positive reviews")
print(top_positive_keywords)
print("Top 5 Keywords that are frequently used in negative reviews")
print(top_negative_keywords)
# Out:
# Top 5 Keywords that are frequently used in positive reviews
# [('stay', 331), ('good', 311), ('hotel', 199), ('goodvery', 192), ('staff', 146)]
# Top 5 Keywords that are frequently used in negative reviews
# [('bad', 43), ('experience', 35), ('hotel', 34), ('stay', 31), ('worst', 25)]
